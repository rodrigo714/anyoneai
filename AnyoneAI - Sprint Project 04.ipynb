# %% [markdown]
# # AnyoneAI - Sprint Project 04
# > Vehicle Classification
#
# You've been learning a lot about Deep Learning Algorithms, now we you're gonna be asked to put it all together.

# %%
import sys

IN_COLAB = "google.colab" in sys.modules
IN_COLAB
# Out:
# False

# %%
if IN_COLAB:
    from google.colab import drive

    drive.mount("/content/drive")

# %%
if IN_COLAB:
    # Put here the full path to the folder having your Sprint project code
    # e.g. "/content/drive/MyDrive/assignment"
    ROOT_DIR = "/content/drive/MyDrive/assignment"
    # %cd $ROOT_DIR

# %% [markdown]
# ## Install dependencies (Only for Colab)

# %%
#if IN_COLAB:
    # This will make sure you have installed all the proper dependencies
    # Instal dependencies
    #!pip install -r requirements.txt
    # We can access to GPUs in Colab, so install GPU version of tensorflow
    #!pip install tensorflow-gpu==2.8.0

# %% [markdown]
# ## 1. Introduction
#
# This is a Multi-class Classification task: we want to predict, given a picture of a vehicle, which of the possible 25 classes is the correct vehicle make-model.
#
# The dataset is composed of JPG images, already stored in folders containing the label (vehicle make-model), separated in train and test sets.

# %%
import os

from tensorflow import keras
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

from src import data_utils, models, config

# %% [markdown]
# ### Getting the data
#
# To access the data for this project, you only need to execute the code below. This will download a zip file `cars_25_dataset.zip` containing inside:
#
# - `car_ims_dataset`: Folder whit train and test images, already classified in sub-folders with the corresponding vehicle label.
#
# - `train_dataset_annos.csv` and `test_dataset_annos.csv`: Train and test images annotations provided in CSV file format. You will not need these files unless you want to solve the optional exercises.

# %% [markdown]
# 1.1. Download the training and test datasets.

# %%
if IN_COLAB:
    config.DATASET_ROOT_PATH = "/content/dataset/"

data_utils.download_datasets(config.DATASET_ROOT_PATH)

# %% [markdown]
# 1.2. Setup some variables you will use during training the model.
#
# The default values used here should work fine for you.

# %%
# Dataset folder
DATASET_FOLDER = os.path.join(config.DATASET_ROOT_PATH, config.DATASET_FILENAME)
DATASET_FOLDER = os.path.join(config.DATASET_ROOT_PATH, "eu-car-dataset_subset")

img_height = 224
img_width = 224
batch_size = 256

# %% [markdown]
# 1.3. Load the training and testing images as a Tensorflow dataset (`tf.data.Dataset`).
#
# Note that it's not a good idea to load all the images into memory because they may need more RAM than the one installed in the system. This is why we create generators using the `image_dataset_from_directory()` function, which loads the images only when they are needed and then releases the memory for loading another batch of new images from the disk.

# %% [markdown]
# **Don't change anything in this cell, just make it run correctly**

# %%
# Load train and test datasets
train_ds = keras.preprocessing.image_dataset_from_directory(
    directory=os.path.join(DATASET_FOLDER, "train"),
    labels="inferred",
    label_mode="categorical",
    seed=123,
    image_size=(img_height, img_width),
    batch_size=batch_size,
)

test_ds = keras.preprocessing.image_dataset_from_directory(
    directory=os.path.join(DATASET_FOLDER, "test"),
    labels="inferred",
    label_mode="categorical",
    seed=123,
    image_size=(img_height, img_width),
    batch_size=batch_size,
)
# Out:
# Found 7509 files belonging to 25 classes.
# Found 1875 files belonging to 25 classes.

# %% [markdown]
# **Checkpoint:** The cell above should output the following message:
#
# ```code
# Found 7509 files belonging to 25 classes.
# Found 1875 files belonging to 25 classes.
# ```

# %% [markdown]
# ## 2. Basic EDA
#
# Let's load and display some pictures with their labels.

# %% [markdown]
# 2.1. Take the class names automatically inferred from the data generator and assign to `class_names` variable. We will use this to do some EDA and also to define the output units in the classification layer of our model.

# %% [markdown]
# **Don't change anything in this cell, just make it run correctly**

# %%
class_names = train_ds.class_names
print(class_names)

assert len(class_names) == 25
# Out:
# ['abarth_595-turismo', 'abarth_grande-punto', 'bmw_z4', 'citroen_c-crosser', 'citroen_ds4', 'citroen_nemo', 'dacia_lodgy', 'ford_f-150', 'hyundai_h-350', 'hyundai_i30', 'land-rover_range-rover-velar', 'mercedes-benz_180', 'mercedes-benz_a-180', 'mercedes-benz_b-220', 'mercedes-benz_cla-220', 'mercedes-benz_cls-320', 'mercedes-benz_slk-350', 'mini_cooper-sd', 'nissan_nv400', 'nissan_primastar', 'peugeot_108', 'porsche_991', 'suzuki_ignis', 'volkswagen_fox', 'volkswagen_up!']

# %% [markdown]
# 2.2. Let's show some pictures!
#
# You can re-run the following cell as many times as you want and it will always show a new set of images and labels.

# %% [markdown]
# **Don't change anything in this cell, just make it run correctly**

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[np.argmax(labels[i])])
        plt.axis("off")

# %% [markdown]
# **Don't change anything in this cell, just make it run correctly**

# %%
# Configure data loader for performance
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
test_ds = test_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ## 3. Multi-layer Perceptron
#
# *Now it's time to train our first Neural Network model. For simplicity, we are going to try using an MLP model.*
#
# *A Multi-layer Perceptron (MLP) is a simple neural network consisting of multiple layers of nodes connected by weighted edges. The input and output layers have one node per feature, and one node per target class respectively, while the intermediate layers have an arbitrary number of nodes. MLPs are known to work well for simple classification tasks, but they might not be suitable for image classification, where the input data has a high dimensionality and there are correlations between adjacent pixels.*
#
# ---
#
# Executing the following cell will create a model using the `create_mlp_model()` functions you created and then run the training pipeline for it.
#
# Feel free to change the code below to include any other optimization algorithm or change the default optimizer parameters like the `learning rate`.
#
# It's also a good idea to change and experiment with different parameters for the `fit()` function. Try with more epochs and also adding [callbacks](https://keras.io/api/callbacks/) for saving the best weights (`ModelCheckpoint`), storing training logs (`TensorBoard` or `CSVLogger`), changing learning rate during training depending on the improvements in the loss function (`ReduceLROnPlateau`), etc.
#
# **Important note:** Don't modify the model layers in the `create_mlp_model()` with different parameters to what we asked you to do in the function or you will break the project unit tests. If you want to experiment further with other model settings, feel free to create your own model in a separate function.

# %%
mlp_model = models.create_mlp_model(
    input_shape=(img_height, img_width, 3), num_classes=len(class_names)
)

# Compile the model
mlp_model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=5e-6),
    loss="categorical_crossentropy",
    metrics=["accuracy"],
)

mlp_model.fit(
    train_ds,
    validation_data=test_ds,
    epochs=30,
)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 224, 224, 3)       0
#
#  flatten (Flatten)           (None, 150528)            0
#
#  dense (Dense)               (None, 512)               77070848
#
#  dense_1 (Dense)             (None, 1024)              525312
#
#  dense_2 (Dense)             (None, 512)               524800
#
#  dense_3 (Dense)             (None, 25)                12825
#
# =================================================================
# Total params: 78,133,785
# Trainable params: 78,133,785
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/30
#  59/235 [======>.......................] - ETA: 4:57 - loss: 3.2156 - accuracy: 0.0609
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 12
#       5 # Compile the model
#       6 mlp_model.compile(
#       7     optimizer=keras.optimizers.Adam(learning_rate=5e-6),
#       8     loss="categorical_crossentropy",
#       9     metrics=["accuracy"],
#      10 )
# ---> 12 mlp_model.fit(
#      13     train_ds,
#      14     validation_data=test_ds,
#      15     epochs=30,
#      16 )
#
# File c:\Users\Rodrigo\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\Rodrigo\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\engine\training.py:1570, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1568 logs = tmp_logs
#    1569 end_step = step + data_handler.step_increment
# -> 1570 callbacks.on_train_batch_end(end_step, logs)
#    1571 if self.stop_training:
#    1572     break
#
# File c:\Users\Rodrigo\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\callbacks.py:470, in CallbackList.on_train_batch_end(self, batch, logs)
#     463 """Calls the `on_train_batch_end` methods of its callbacks.
#     464
#     465 Args:
#     466     batch: Integer, index of batch within the current epoch.
#     467     logs: Dict. Aggregated metric results up until this batch.
#     468 """
#     469 if self._should_call_train_batch_hooks:
# --> 470     self._call_batch_hook(ModeKeys.TRAIN, "end", batch, logs=logs)
#
# File c:\Users\Rodrigo\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\callbacks.py:317, in CallbackList._call_batch_hook(self, mode, hook, batch, logs)
#     315     self._call_batch_begin_hook(mode, batch, logs)
#     316 elif hook == "end":
# --> 317     self._call_batch_end_hook(mode, batch, logs)
#     318 else:
#     319     raise ValueError(
#     320         f"Unrecognized hook: {hook}. "
#     321         'Expected values are ["begin", "end"]'
#     322     )
#
# File c:\Users\Rodrigo\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\callbacks.py:340, in CallbackList._call_batch_end_hook(self, mode, batch, logs)
#     337     batch_time = time.time() - self._batch_start_time
#     338     self._batch_times.append(batch_time)
# --> 340 self._call_batch_hook_helper(hook_name, batch, logs)
#     342 if len(self._batch_times) >= self._num_batches_for_timing_check:
#     343     end_hook_name = hook_name
#
# File c:\Users\Rodrigo\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\callbacks.py:388, in CallbackList._call_batch_hook_helper(self, hook_name, batch, logs)
#     386 for callback in self.callbacks:
#     387     hook = getattr(callback, hook_name)
# --> 388     hook(batch, logs)
#     390 if self._check_timing:
#     391     if hook_name not in self._hook_times:
#
# File c:\Users\Rodrigo\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\callbacks.py:1081, in ProgbarLogger.on_train_batch_end(self, batch, logs)
#    1080 def on_train_batch_end(self, batch, logs=None):
# -> 1081     self._batch_update_progbar(batch, logs)
#
# File c:\Users\Rodrigo\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\callbacks.py:1157, in ProgbarLogger._batch_update_progbar(self, batch, logs)
#    1153     self.seen += add_seen
#    1155 if self.verbose == 1:
#    1156     # Only block async when verbose = 1.
# -> 1157     logs = tf_utils.sync_to_numpy_or_python_type(logs)
#    1158     self.progbar.update(self.seen, list(logs.items()), finalize=False)
#
# File c:\Users\Rodrigo\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\utils\tf_utils.py:635, in sync_to_numpy_or_python_type(tensors)
#     632         return t
#     633     return t.item() if np.ndim(t) == 0 else t
# --> 635 return tf.nest.map_structure(_to_single_numpy_or_python_type, tensors)
#
# File c:\Users\Rodrigo\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\util\nest.py:917, in map_structure(func, *structure, **kwargs)
#     913 flat_structure = (flatten(s, expand_composites) for s in structure)
#     914 entries = zip(*flat_structure)
#     916 return pack_sequence_as(
# --> 917     structure[0], [func(*x) for x in entries],
#     918     expand_composites=expand_composites)
#
# File c:\Users\Rodrigo\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\util\nest.py:917, in <listcomp>(.0)
#     913 flat_structure = (flatten(s, expand_composites) for s in structure)
#     914 entries = zip(*flat_structure)
#     916 return pack_sequence_as(
# --> 917     structure[0], [func(*x) for x in entries],
#     918     expand_composites=expand_composites)
#
# File c:\Users\Rodrigo\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\utils\tf_utils.py:628, in sync_to_numpy_or_python_type.<locals>._to_single_numpy_or_python_type(t)
#     625 def _to_single_numpy_or_python_type(t):
#     626     # Don't turn ragged or sparse tensors to NumPy.
#     627     if isinstance(t, tf.Tensor):
# --> 628         t = t.numpy()
#     629     # Strings, ragged and sparse tensors don't have .item(). Return them
#     630     # as-is.
#     631     if not isinstance(t, (np.ndarray, np.generic)):
#
# File c:\Users\Rodrigo\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\framework\ops.py:1157, in _EagerTensorBase.numpy(self)
#    1134 """Copy of the contents of this Tensor into a NumPy array or scalar.
#    1135
#    1136 Unlike NumPy arrays, Tensors are immutable, so this method has to copy
#    (...)
#    1154     NumPy dtype.
#    1155 """
#    1156 # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1157 maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1158 return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#
# File c:\Users\Rodrigo\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\framework\ops.py:1123, in _EagerTensorBase._numpy(self)
#    1121 def _numpy(self):
#    1122   try:
# -> 1123     return self._numpy_internal()
#    1124   except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1125     raise core._status_to_exception(e) from None
#
# KeyboardInterrupt:

# %% [markdown]
# At this point the model accuracy in the validation dataset should be around *0.3*.
#
# What do you think about the relation between training accuracy and validation accuracy? Is the model overfitting or underfitting?
#
# What changes can we apply to reach our goal of 0.8 (80%) accuracy on testing?

# %% [markdown]
# ## 4. CNN: LeNet
#
# *Multi-layer Perceptrons are known to work well for simple classification tasks, but they might not be suitable for image classification, where the input data has a high dimensionality and there are correlations between adjacent pixels.*
#
# *If the previous model wasn't enough for the accuracy we aim to achieve, we can try a bigger one, a Convolutional Network! We are going to use the first develop CNN, the LeNet model.*
#
# *LeNet is a type of Convolutional Neural Network (CNN) that was specifically designed for image classification. LeNet uses a set of convolutional layers to extract low-level features such as edges and corners, and then combines them into higher-level features through a series of pooling layers. Finally, a set of fully connected layers is used to classify the images. LeNet has shown to be very effective in image classification tasks, especially in cases where the input images are small and the features are not too complex.*
#
# ---
#
# Executing the following cell will create a model using the `create_lenet_model()` function you created and then run the training pipeline for it.
#
# Feel free to change the code below to include any other optimization algorithm or change the default optimizer parameters like the `learning rate`.
#
# It's also a good idea to change and experiment with different parameters for the `fit()` function. Try with more epochs and also adding [callbacks](https://keras.io/api/callbacks/) for saving the best weights (`ModelCheckpoint`), storing training logs (`TensorBoard` or `CSVLogger`), changing learning rate during training depending on the improvements in the loss function (`ReduceLROnPlateau`), etc.
#
# **Important note:** Don't modify the model layers in the `create_lenet_model()` with different parameters to what we asked you to do in the function or you will break the project unit tests. If you want to experiment further with other model settings, feel free to create your own model in a separate function.

# %%
lenet_model = models.create_lenet_model(
    input_shape=(img_height, img_width, 3), num_classes=len(class_names)
)

# Compile the model
lenet_model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=5e-5),
    loss="categorical_crossentropy",
    metrics=["accuracy"],
)

lenet_model.fit(
    train_ds,
    validation_data=test_ds,
    epochs=20,
)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 224, 224, 3)       0
#
#  conv2d (Conv2D)             (None, 220, 220, 6)       456
#
#  average_pooling2d (AverageP  (None, 110, 110, 6)      0
#  ooling2D)
#
#  conv2d_1 (Conv2D)           (None, 106, 106, 16)      2416
#
#  average_pooling2d_1 (Averag  (None, 53, 53, 16)       0
#  ePooling2D)
#
#  flatten_1 (Flatten)         (None, 44944)             0
#
#  dense_1 (Dense)             (None, 120)               5393400
#
#  dense_2 (Dense)             (None, 84)                10164
#
#  dense_3 (Dense)             (None, 25)                2125
#
# =================================================================
# Total params: 5,408,561
# Trainable params: 5,408,561
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/20
# 235/235 [==============================] - 33s 139ms/step - loss: 3.1107 - accuracy: 0.0996 - val_loss: 2.9751 - val_accuracy: 0.1419
# Epoch 2/20
# 235/235 [==============================] - 33s 139ms/step - loss: 2.7303 - accuracy: 0.2376 - val_loss: 2.7291 - val_accuracy: 0.2293
# Epoch 3/20
# 235/235 [==============================] - 33s 139ms/step - loss: 2.3570 - accuracy: 0.3779 - val_loss: 2.6169 - val_accuracy: 0.2757
# Epoch 4/20
# 235/235 [==============================] - 33s 139ms/step - loss: 2.0815 - accuracy: 0.4737 - val_loss: 2.5551 - val_accuracy: 0.2944
# Epoch 5/20
# 235/235 [==============================] - 32s 138ms/step - loss: 1.8523 - accuracy: 0.5572 - val_loss: 2.5509 - val_accuracy: 0.2923
# Epoch 6/20
# 235/235 [==============================] - 33s 139ms/step - loss: 1.6561 - accuracy: 0.6260 - val_loss: 2.5312 - val_accuracy: 0.3067
# Epoch 7/20
# 235/235 [==============================] - 33s 139ms/step - loss: 1.4692 - accuracy: 0.6865 - val_loss: 2.5183 - val_accuracy: 0.3115
# Epoch 8/20
# 235/235 [==============================] - 33s 139ms/step - loss: 1.2968 - accuracy: 0.7414 - val_loss: 2.5363 - val_accuracy: 0.3067
# Epoch 9/20
# 235/235 [==============================] - 33s 140ms/step - loss: 1.1408 - accuracy: 0.7925 - val_loss: 2.5401 - val_accuracy: 0.3061
# Epoch 10/20
# 235/235 [==============================] - 33s 141ms/step - loss: 0.9904 - accuracy: 0.8350 - val_loss: 2.5573 - val_accuracy: 0.3077
# Epoch 11/20
# 235/235 [==============================] - 33s 142ms/step - loss: 0.8525 - accuracy: 0.8788 - val_loss: 2.5827 - val_accuracy: 0.3077
# Epoch 12/20
# 235/235 [==============================] - 33s 139ms/step - loss: 0.7257 - accuracy: 0.9173 - val_loss: 2.6059 - val_accuracy: 0.3003
# Epoch 13/20
# 235/235 [==============================] - 33s 140ms/step - loss: 0.6126 - accuracy: 0.9451 - val_loss: 2.6089 - val_accuracy: 0.3093
# Epoch 14/20
# 235/235 [==============================] - 33s 139ms/step - loss: 0.5097 - accuracy: 0.9660 - val_loss: 2.6416 - val_accuracy: 0.3077
# Epoch 15/20
# 235/235 [==============================] - 33s 139ms/step - loss: 0.4229 - accuracy: 0.9806 - val_loss: 2.6659 - val_accuracy: 0.3003
# Epoch 16/20
# 235/235 [==============================] - 33s 140ms/step - loss: 0.3482 - accuracy: 0.9887 - val_loss: 2.7160 - val_accuracy: 0.2981
# Epoch 17/20
# 235/235 [==============================] - 33s 139ms/step - loss: 0.2851 - accuracy: 0.9928 - val_loss: 2.7325 - val_accuracy: 0.2955
# Epoch 18/20
# 235/235 [==============================] - 33s 139ms/step - loss: 0.2330 - accuracy: 0.9955 - val_loss: 2.7650 - val_accuracy: 0.2933
# Epoch 19/20
# 235/235 [==============================] - 33s 139ms/step - loss: 0.1921 - accuracy: 0.9973 - val_loss: 2.7854 - val_accuracy: 0.2885
# Epoch 20/20
# 235/235 [==============================] - 33s 139ms/step - loss: 0.1588 - accuracy: 0.9984 - val_loss: 2.8005 - val_accuracy: 0.2912

# %% [markdown]
# At this point the model accuracy in the validation dataset should be around *0.3*.
#
# What do you think about the relation between training accuracy and validation accuracy? Is the model overfitting or underfitting?
#
# What changes can we apply to reach our goal of 0.8 (80%) accuracy on testing?

# %% [markdown]
# ## 5. CNN: Transfer learning from ResNet50
#
# *Maybe the LeNet is still no the best choice for our task. Actually, most of the time, when solving image classification problems, the best results are achieved using pre-built CNN architecture pre-trained on imagenet dataset. This process is commonly known as **transfer learning** or **fine-tuning**.*
#
# *ResNet50, is a much deeper CNN that was developed to tackle the problem of vanishing gradients in deep neural networks. ResNet50 is made up of many layers that are organized into blocks, each of which has a set of convolutional layers followed by shortcut connections that allow for the easy flow of information between layers. These shortcut connections help to prevent vanishing gradients and allow the network to learn very deep representations of the input images. This makes ResNet50 ideal for image classification tasks where the input images are complex and large.*
#
# *Therefore, it would be better to use ResNet50 finetuning for image classification tasks, especially if the input images are complex and large, as it has been optimized for this specific task and has shown to be very effective in achieving state-of-the-art results. Additionally, using ResNet50 finetuning means that the model can take advantage of the pre-trained weights on a large dataset, which can lead to faster convergence and better performance on smaller datasets.*
#
# ---
#
# Executing the following cell will create a model using the `create_resnet50_model()` function you created and then run the training pipeline for it.
#
# Feel free to change the code below to include any other optimization algorithm or change the default optimizer parameters like the `learning rate`.
#
# It's also a good idea to change and experiment with different parameters for the `fit()` function. Try with more epochs and also adding [callbacks](https://keras.io/api/callbacks/) for saving the best weights (`ModelCheckpoint`), storing training logs (`TensorBoard` or `CSVLogger`), changing learning rate during training depending on the improvements in the loss function (`ReduceLROnPlateau`), etc.
#
# **Important note:** Don't modify the model layers in the `create_resnet50_model()` with different parameters to what we asked you to do in the function or you will break the project unit tests. If you want to experiment further with other model settings, feel free to create your own model in a separate function.

# %%
from keras import layers
from keras.callbacks import ReduceLROnPlateau, EarlyStopping

inputs = keras.Input(shape=(img_height, img_width, 3))

data_augmentation = keras.Sequential(
    [
        layers.RandomFlip("horizontal_and_vertical"),                           # Volteo horizontal y vertical
        layers.RandomRotation(0.5),                                             # Rotación aleatoria
        layers.RandomZoom(0.5),                                                 # Zoom aleatorio
        layers.RandomBrightness(0.1),                                           # Brillo aleatorio
        layers.RandomContrast(0.1),                                             # Contraste aleatorio
        layers.Lambda(lambda x: tf.image.random_saturation(x, 0.6, 1.4)),       # Saturación aleatoria
        layers.Lambda(lambda x: tf.image.random_hue(x, 0.2)),                   # Tono aleatorio
        layers.RandomTranslation(height_factor=0.1, width_factor=0.1),          # Traslación aleatoria
        layers.RandomCrop(height=img_height, width=img_width),                  # Recorte aleatorio
        layers.RandomHeight(factor=0.1),                                        # Altura aleatoria
        layers.RandomWidth(factor=0.1),                                         # Ancho aleatorio
        layers.GaussianNoise(0.1),                                              # Ruido gaussiano
        layers.Lambda(lambda x: tf.image.random_brightness(x, max_delta=0.1)),  # Brillo aleatorio (versión alternativa)
        layers.Lambda(lambda x: tf.image.random_flip_left_right(x)),            # Volteo aleatorio izquierdo-derecho
        layers.Lambda(lambda x: tf.image.random_flip_up_down(x))                # Volteo aleatorio arriba-abajo
    ]
)

augmented_inputs = data_augmentation(inputs)
preprocessed_inputs = keras.applications.resnet50.preprocess_input(augmented_inputs)

resnet50_model = models.create_resnet50_model(
    input_shape=preprocessed_inputs.shape[1:], 
    num_classes=len(class_names)
)

# Compile the model
resnet50_model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=5e-4, beta_1=0.9, beta_2=0.999),
    loss="categorical_crossentropy",
    metrics=["accuracy"],
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_loss', 
    factor=0.5, 
    patience=3, 
    min_lr=1e-6
)

early_stopping = EarlyStopping(patience=3, restore_best_weights=True)

resnet50_model.fit(
    train_ds,
    validation_data=test_ds,
    epochs=20,
    callbacks=[lr_scheduler, early_stopping]
)
# Out:
# Model: "sequential_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 7, 7, 2048)        23587712
#
#  flatten_7 (Flatten)         (None, 100352)            0
#
#  dropout_7 (Dropout)         (None, 100352)            0
#
#  dense_7 (Dense)             (None, 25)                2508825
#
# =================================================================
# Total params: 26,096,537
# Trainable params: 2,508,825
# Non-trainable params: 23,587,712
# _________________________________________________________________
# None
# Epoch 1/20
# 30/30 [==============================] - 43s 1s/step - loss: 6.1147 - accuracy: 0.4005 - val_loss: 1.9403 - val_accuracy: 0.6699 - lr: 5.0000e-04
# Epoch 2/20
# 30/30 [==============================] - 31s 1s/step - loss: 0.5146 - accuracy: 0.8847 - val_loss: 1.5847 - val_accuracy: 0.7381 - lr: 5.0000e-04
# Epoch 3/20
# 30/30 [==============================] - 31s 1s/step - loss: 0.1483 - accuracy: 0.9558 - val_loss: 1.1952 - val_accuracy: 0.7851 - lr: 5.0000e-04
# Epoch 4/20
# 30/30 [==============================] - 31s 1s/step - loss: 0.0721 - accuracy: 0.9783 - val_loss: 1.3146 - val_accuracy: 0.7867 - lr: 5.0000e-04
# Epoch 5/20
# 30/30 [==============================] - 31s 1s/step - loss: 0.0469 - accuracy: 0.9854 - val_loss: 1.2501 - val_accuracy: 0.7813 - lr: 5.0000e-04
# Epoch 6/20
# 30/30 [==============================] - 31s 1s/step - loss: 0.0274 - accuracy: 0.9901 - val_loss: 1.2436 - val_accuracy: 0.7856 - lr: 5.0000e-04

# %% [markdown]
# At this point the model accuracy in the validation dataset should be around *0.7*.
#
# What do you think about the relation between training accuracy and validation accuracy? Is the model overfitting or underfitting?
#
# What changes can we apply to reach our goal of 0.8 (80%) accuracy on testing?

# %% [markdown]
# ## 6. Analyze model results
#
# Choose your best model and report some metrics on the results you obtained.
#
# You can plot a confussion matrix or use [Scikit-learn classification report](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.classification_report.html).

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

# Obtén las etiquetas verdaderas
y_true = np.concatenate([y for x, y in test_ds], axis=0)
if y_true.ndim > 1 and y_true.shape[1] > 1:
    y_true = np.argmax(y_true, axis=1)

# Obtén las predicciones del modelo
y_pred = resnet50_model.predict(test_ds)
y_pred_classes = np.argmax(y_pred, axis=1)

# Imprime el reporte de clasificación
print(classification_report(y_true, y_pred_classes, target_names=class_names))

# Calcula y visualiza la matriz de confusión
cm = confusion_matrix(y_true, y_pred_classes)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)

# Dibuja la matriz de confusión
fig, ax = plt.subplots(figsize=(12, 12))  # Ajusta el tamaño según sea necesario
disp.plot(cmap='Blues', ax=ax)

# Rota las etiquetas del eje x
plt.xticks(rotation=90, ha='right')
plt.yticks(rotation=0)

plt.show()
# Out:
# 8/8 [==============================] - 7s 834ms/step
#                               precision    recall  f1-score   support
#
#           abarth_595-turismo       0.91      0.90      0.91        80
#          abarth_grande-punto       0.86      0.77      0.81        78
#                       bmw_z4       0.88      0.80      0.84        80
#            citroen_c-crosser       0.78      0.90      0.84        77
#                  citroen_ds4       0.94      0.75      0.83        80
#                 citroen_nemo       0.94      0.96      0.95        80
#                  dacia_lodgy       0.95      0.90      0.92        80
#                   ford_f-150       0.96      0.89      0.92        80
#                hyundai_h-350       0.84      0.70      0.76        46
#                  hyundai_i30       0.64      0.70      0.67        80
# land-rover_range-rover-velar       0.80      0.95      0.87        43
#            mercedes-benz_180       0.42      0.44      0.43        80
#          mercedes-benz_a-180       0.49      0.59      0.54        80
#          mercedes-benz_b-220       0.62      0.62      0.62        69
#        mercedes-benz_cla-220       0.58      0.75      0.65        80
#        mercedes-benz_cls-320       0.79      0.66      0.72        80
#        mercedes-benz_slk-350       0.86      0.63      0.73        76
#               mini_cooper-sd       0.86      0.89      0.87        80
#                 nissan_nv400       0.80      0.90      0.85        80
#             nissan_primastar       0.85      0.87      0.86        46
#                  peugeot_108       0.82      0.72      0.77        80
#                  porsche_991       0.74      0.86      0.80        80
#                 suzuki_ignis       0.90      0.88      0.89        80
#               volkswagen_fox       0.79      0.84      0.81        80
#               volkswagen_up!       0.90      0.81      0.86        80
#
#                     accuracy                           0.79      1875
#                    macro avg       0.80      0.79      0.79      1875
#                 weighted avg       0.80      0.79      0.79      1875

# %% [markdown]
# ## 7. Optional. Make your own model
#
# The models we've trained before are just a limited set over the universe of stuff you can use.
#
# You still have a lot of things to experiment with to increase accuracy, some ideas are:
#
# 1. Use any other CNN architecture you think may perform better than ResNet50.
# 2. Try adding data augmentation or any other regularization algorithms.
# 3. Train using more epochs, a different optimization algorithm, etc.
# 4. Check [KerasTuner](https://keras.io/api/keras_tuner/) documentation about how to efficiently test a lot of different architectures and parameters.

# %%
from keras import layers
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.optimizers import Nadam
from keras.applications import ResNet50

inputs = keras.Input(shape=(img_height, img_width, 3))

data_augmentation = keras.Sequential(
    [
        layers.RandomFlip("horizontal_and_vertical"),                           # Volteo horizontal y vertical
        layers.RandomRotation(0.5),                                             # Rotación aleatoria
        layers.RandomZoom(0.5),                                                 # Zoom aleatorio
        layers.RandomBrightness(0.5),                                           # Brillo aleatorio
        layers.RandomContrast(0.5),                                             # Contraste aleatorio
        layers.Lambda(lambda x: tf.image.random_saturation(x, 0.6, 1.4)),       # Saturación aleatoria
        layers.Lambda(lambda x: tf.image.random_hue(x, 0.2)),                   # Tono aleatorio
        layers.RandomTranslation(height_factor=0.1, width_factor=0.1),          # Traslación aleatoria
        layers.RandomCrop(height=img_height, width=img_width),                  # Recorte aleatorio
        layers.RandomHeight(factor=0.5),                                        # Altura aleatoria
        layers.RandomWidth(factor=0.5),                                         # Ancho aleatorio
        layers.GaussianNoise(0.5),                                              # Ruido gaussiano
        layers.GaussianDropout(0.5),
        layers.Lambda(lambda x: tf.image.random_brightness(x, max_delta=0.1)),  # Brillo aleatorio (versión alternativa)
        layers.Lambda(lambda x: tf.image.random_flip_left_right(x)),            # Volteo aleatorio izquierdo-derecho
        layers.Lambda(lambda x: tf.image.random_flip_up_down(x))                # Volteo aleatorio arriba-abajo
    ]
)

augmented_inputs = data_augmentation(inputs)
preprocessed_inputs = keras.applications.resnet50.preprocess_input(augmented_inputs)
num_classes=len(class_names)

resnet50 = ResNet50(
    input_shape=preprocessed_inputs.shape[1:], 
    weights='imagenet', 
    include_top=False,
)

for layer in resnet50.layers:
    layer.trainable = False

model = keras.Sequential()
model.add(resnet50)
model.add(layers.GlobalAveragePooling2D())  # Puedes cambiar a Flatten si prefieres
model.add(layers.Dropout(0.5))
model.add(layers.Dense(512, activation="relu"))  # Capa densa adicional
model.add(layers.BatchNormalization())
model.add(layers.Dense(num_classes, activation="softmax"))
print(model.summary())

# Compile the model
model.compile(
    optimizer=Nadam(learning_rate=1e-3),
    loss="categorical_crossentropy",
    metrics=["accuracy"],
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_loss', 
    factor=0.5, 
    patience=2,
    min_lr=1e-6
)

early_stopping = EarlyStopping(patience=4, restore_best_weights=True)

model.fit(
    train_ds,
    validation_data=test_ds,
    epochs=20,
    callbacks=[lr_scheduler, early_stopping]
)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 7, 7, 2048)        23587712
#
#  global_average_pooling2d_1   (None, 2048)             0
#  (GlobalAveragePooling2D)
#
#  dropout_1 (Dropout)         (None, 2048)              0
#
#  dense_2 (Dense)             (None, 512)               1049088
#
#  batch_normalization_1 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dense_3 (Dense)             (None, 25)                12825
#
# =================================================================
# Total params: 24,651,673
# Trainable params: 1,062,937
# Non-trainable params: 23,588,736
# _________________________________________________________________
# None
# Epoch 1/20
# 30/30 [==============================] - 49s 1s/step - loss: 2.5390 - accuracy: 0.3088 - val_loss: 2.4952 - val_accuracy: 0.2987 - lr: 0.0010
# Epoch 2/20
# 30/30 [==============================] - 31s 1s/step - loss: 1.4294 - accuracy: 0.5768 - val_loss: 1.7572 - val_accuracy: 0.4581 - lr: 0.0010
# Epoch 3/20
# 30/30 [==============================] - 31s 1s/step - loss: 1.1263 - accuracy: 0.6628 - val_loss: 1.1650 - val_accuracy: 0.6549 - lr: 0.0010
# Epoch 4/20
# 30/30 [==============================] - 31s 1s/step - loss: 0.9559 - accuracy: 0.7134 - val_loss: 0.9856 - val_accuracy: 0.7243 - lr: 0.0010
# Epoch 5/20
# 30/30 [==============================] - 31s 1s/step - loss: 0.8567 - accuracy: 0.7353 - val_loss: 0.9165 - val_accuracy: 0.7259 - lr: 0.0010
# Epoch 6/20
# 30/30 [==============================] - 31s 1s/step - loss: 0.7820 - accuracy: 0.7587 - val_loss: 0.8810 - val_accuracy: 0.7349 - lr: 0.0010
# Epoch 7/20
# 30/30 [==============================] - 31s 1s/step - loss: 0.7176 - accuracy: 0.7784 - val_loss: 0.8445 - val_accuracy: 0.7445 - lr: 0.0010
# Epoch 8/20
# 30/30 [==============================] - 31s 1s/step - loss: 0.6804 - accuracy: 0.7926 - val_loss: 0.8435 - val_accuracy: 0.7520 - lr: 0.0010
# Epoch 9/20
# 30/30 [==============================] - 31s 1s/step - loss: 0.6346 - accuracy: 0.8001 - val_loss: 0.7974 - val_accuracy: 0.7595 - lr: 0.0010
# Epoch 10/20
# 30/30 [==============================] - 31s 1s/step - loss: 0.6161 - accuracy: 0.8068 - val_loss: 0.7975 - val_accuracy: 0.7483 - lr: 0.0010
# Epoch 11/20
# 30/30 [==============================] - 31s 1s/step - loss: 0.5737 - accuracy: 0.8178 - val_loss: 0.7535 - val_accuracy: 0.7765 - lr: 0.0010
# Epoch 12/20
# 30/30 [==============================] - 31s 1s/step - loss: 0.5565 - accuracy: 0.8213 - val_loss: 0.7994 - val_accuracy: 0.7659 - lr: 0.0010
# Epoch 13/20
# 30/30 [==============================] - 31s 1s/step - loss: 0.5297 - accuracy: 0.8326 - val_loss: 0.7825 - val_accuracy: 0.7653 - lr: 0.0010
# Epoch 14/20
# 30/30 [==============================] - 31s 1s/step - loss: 0.4889 - accuracy: 0.8463 - val_loss: 0.7462 - val_accuracy: 0.7765 - lr: 5.0000e-04
# Epoch 15/20
# 30/30 [==============================] - 31s 1s/step - loss: 0.4516 - accuracy: 0.8592 - val_loss: 0.7500 - val_accuracy: 0.7819 - lr: 5.0000e-04
# Epoch 16/20
# 30/30 [==============================] - 31s 1s/step - loss: 0.4329 - accuracy: 0.8675 - val_loss: 0.7094 - val_accuracy: 0.7840 - lr: 5.0000e-04
# Epoch 17/20
# 30/30 [==============================] - 31s 1s/step - loss: 0.4120 - accuracy: 0.8680 - val_loss: 0.6941 - val_accuracy: 0.7845 - lr: 5.0000e-04
# Epoch 18/20
# 30/30 [==============================] - 31s 1s/step - loss: 0.4052 - accuracy: 0.8731 - val_loss: 0.6721 - val_accuracy: 0.8000 - lr: 5.0000e-04
# Epoch 19/20
# 30/30 [==============================] - 31s 1s/step - loss: 0.3922 - accuracy: 0.8772 - val_loss: 0.6765 - val_accuracy: 0.7931 - lr: 5.0000e-04
# Epoch 20/20
# 30/30 [==============================] - 31s 1s/step - loss: 0.3790 - accuracy: 0.8783 - val_loss: 0.6790 - val_accuracy: 0.7920 - lr: 5.0000e-04

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

y_true = np.concatenate([y for x, y in test_ds], axis=0)
if y_true.ndim > 1 and y_true.shape[1] > 1:
    y_true = np.argmax(y_true, axis=1)

y_pred = model.predict(test_ds)
y_pred_classes = np.argmax(y_pred, axis=1)

print(classification_report(y_true, y_pred_classes, target_names=class_names))

cm = confusion_matrix(y_true, y_pred_classes)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)

fig, ax = plt.subplots(figsize=(12, 12))
disp.plot(cmap='Blues', ax=ax)

plt.xticks(rotation=90, ha='right')
plt.yticks(rotation=0)

plt.show()
# Out:
# 8/8 [==============================] - 7s 837ms/step
#                               precision    recall  f1-score   support
#
#           abarth_595-turismo       0.92      0.88      0.90        80
#          abarth_grande-punto       0.92      0.77      0.84        78
#                       bmw_z4       0.86      0.88      0.87        80
#            citroen_c-crosser       0.90      0.78      0.83        77
#                  citroen_ds4       0.79      0.85      0.82        80
#                 citroen_nemo       0.87      0.96      0.91        80
#                  dacia_lodgy       0.78      0.97      0.87        80
#                   ford_f-150       0.99      0.97      0.98        80
#                hyundai_h-350       0.79      0.74      0.76        46
#                  hyundai_i30       0.66      0.65      0.65        80
# land-rover_range-rover-velar       0.97      0.91      0.94        43
#            mercedes-benz_180       0.37      0.47      0.42        80
#          mercedes-benz_a-180       0.56      0.68      0.61        80
#          mercedes-benz_b-220       0.71      0.54      0.61        69
#        mercedes-benz_cla-220       0.65      0.64      0.64        80
#        mercedes-benz_cls-320       0.64      0.78      0.70        80
#        mercedes-benz_slk-350       0.84      0.61      0.70        76
#               mini_cooper-sd       0.92      0.86      0.89        80
#                 nissan_nv400       0.88      0.81      0.84        80
#             nissan_primastar       0.88      0.96      0.92        46
#                  peugeot_108       0.79      0.76      0.78        80
#                  porsche_991       0.83      0.84      0.83        80
#                 suzuki_ignis       0.92      0.88      0.90        80
#               volkswagen_fox       0.84      0.90      0.87        80
#               volkswagen_up!       0.90      0.79      0.84        80
#
#                     accuracy                           0.79      1875
#                    macro avg       0.81      0.79      0.80      1875
#                 weighted avg       0.80      0.79      0.79      1875

# %%
# %run inceptionV3.py
# Out:
# Found 7509 files belonging to 25 classes.
# Found 1875 files belonging to 25 classes.
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inception_v3 (Functional)   (None, 5, 5, 2048)        21802784
#
#  global_average_pooling2d_2   (None, 2048)             0
#  (GlobalAveragePooling2D)
#
#  batch_normalization_284 (Ba  (None, 2048)             8192
#  tchNormalization)
#
#  dense_2 (Dense)             (None, 25)                51225
#
# =================================================================
# Total params: 21,862,201
# Trainable params: 55,321
# Non-trainable params: 21,806,880
# _________________________________________________________________
# None
# Epoch 1/50
# 30/30 [==============================] - 43s 854ms/step - loss: 3.4000 - accuracy: 0.0907 - val_loss: 4.7262 - val_accuracy: 0.0907 - lr: 0.0010
# Epoch 2/50
# 30/30 [==============================] - 18s 607ms/step - loss: 2.9035 - accuracy: 0.1699 - val_loss: 3.4733 - val_accuracy: 0.1280 - lr: 0.0010
# Epoch 3/50
# 30/30 [==============================] - 17s 561ms/step - loss: 2.6770 - accuracy: 0.2164 - val_loss: 3.2940 - val_accuracy: 0.1269 - lr: 0.0010
# Epoch 4/50
# 30/30 [==============================] - 17s 561ms/step - loss: 2.5405 - accuracy: 0.2634 - val_loss: 3.0862 - val_accuracy: 0.1717 - lr: 0.0010
# Epoch 5/50
# 30/30 [==============================] - 17s 561ms/step - loss: 2.4454 - accuracy: 0.2958 - val_loss: 3.0440 - val_accuracy: 0.1771 - lr: 0.0010
# Epoch 6/50
# 30/30 [==============================] - 17s 561ms/step - loss: 2.3355 - accuracy: 0.3256 - val_loss: 2.9776 - val_accuracy: 0.1803 - lr: 0.0010
# Epoch 7/50
# 30/30 [==============================] - 17s 563ms/step - loss: 2.2708 - accuracy: 0.3419 - val_loss: 2.9331 - val_accuracy: 0.1840 - lr: 0.0010
# Epoch 8/50
# 30/30 [==============================] - 17s 568ms/step - loss: 2.1671 - accuracy: 0.3730 - val_loss: 2.9221 - val_accuracy: 0.1925 - lr: 0.0010
# Epoch 9/50
# 30/30 [==============================] - 17s 564ms/step - loss: 2.1207 - accuracy: 0.3865 - val_loss: 2.9015 - val_accuracy: 0.2027 - lr: 0.0010
# Epoch 10/50
# 30/30 [==============================] - 16s 551ms/step - loss: 2.0441 - accuracy: 0.4119 - val_loss: 2.9550 - val_accuracy: 0.1936 - lr: 0.0010
# Epoch 11/50
# 30/30 [==============================] - 17s 569ms/step - loss: 1.9998 - accuracy: 0.4274 - val_loss: 2.9003 - val_accuracy: 0.1995 - lr: 0.0010
# Epoch 12/50
# 30/30 [==============================] - 16s 550ms/step - loss: 1.9436 - accuracy: 0.4456 - val_loss: 2.9364 - val_accuracy: 0.2027 - lr: 0.0010
# Epoch 13/50
# 30/30 [==============================] - 16s 551ms/step - loss: 1.9097 - accuracy: 0.4536 - val_loss: 2.9384 - val_accuracy: 0.2032 - lr: 0.0010
# Epoch 14/50
# 30/30 [==============================] - 17s 555ms/step - loss: 1.8143 - accuracy: 0.4889 - val_loss: 2.9008 - val_accuracy: 0.2069 - lr: 5.0000e-04
# Epoch 15/50
# 30/30 [==============================] - 17s 563ms/step - loss: 1.7884 - accuracy: 0.4962 - val_loss: 2.8910 - val_accuracy: 0.2037 - lr: 5.0000e-04
# Epoch 16/50
# 30/30 [==============================] - 16s 550ms/step - loss: 1.7693 - accuracy: 0.5055 - val_loss: 2.9111 - val_accuracy: 0.2091 - lr: 5.0000e-04
# Epoch 17/50
# 30/30 [==============================] - 16s 551ms/step - loss: 1.7501 - accuracy: 0.5074 - val_loss: 2.9267 - val_accuracy: 0.2123 - lr: 5.0000e-04
# Epoch 18/50
# 30/30 [==============================] - 17s 562ms/step - loss: 1.7091 - accuracy: 0.5267 - val_loss: 2.8845 - val_accuracy: 0.2155 - lr: 2.5000e-04
# Epoch 19/50
# 30/30 [==============================] - 16s 563ms/step - loss: 1.6981 - accuracy: 0.5286 - val_loss: 2.8878 - val_accuracy: 0.2123 - lr: 2.5000e-04
# Epoch 20/50
# 30/30 [==============================] - 16s 551ms/step - loss: 1.6876 - accuracy: 0.5332 - val_loss: 2.9009 - val_accuracy: 0.2112 - lr: 2.5000e-04
# Epoch 21/50
# 30/30 [==============================] - 16s 552ms/step - loss: 1.6674 - accuracy: 0.5406 - val_loss: 2.8973 - val_accuracy: 0.2197 - lr: 1.2500e-04
# Epoch 22/50
# 30/30 [==============================] - 16s 552ms/step - loss: 1.6605 - accuracy: 0.5455 - val_loss: 2.8981 - val_accuracy: 0.2160 - lr: 1.2500e-04
# Epoch 23/50
# 30/30 [==============================] - 17s 555ms/step - loss: 1.6519 - accuracy: 0.5487 - val_loss: 2.8931 - val_accuracy: 0.2203 - lr: 6.2500e-05
# 8/8 [==============================] - 5s 442ms/step
#                               precision    recall  f1-score   support
#
#           abarth_595-turismo       0.15      0.14      0.14        80
#          abarth_grande-punto       0.25      0.15      0.19        78
#                       bmw_z4       0.25      0.28      0.26        80
#            citroen_c-crosser       0.25      0.25      0.25        77
#                  citroen_ds4       0.15      0.14      0.14        80
#                 citroen_nemo       0.41      0.41      0.41        80
#                  dacia_lodgy       0.33      0.33      0.33        80
#                   ford_f-150       0.23      0.29      0.26        80
#                hyundai_h-350       0.37      0.24      0.29        46
#                  hyundai_i30       0.10      0.11      0.10        80
# land-rover_range-rover-velar       0.49      0.70      0.58        43
#            mercedes-benz_180       0.06      0.05      0.05        80
#          mercedes-benz_a-180       0.16      0.14      0.15        80
#          mercedes-benz_b-220       0.09      0.09      0.09        69
#        mercedes-benz_cla-220       0.13      0.14      0.13        80
#        mercedes-benz_cls-320       0.16      0.14      0.15        80
#        mercedes-benz_slk-350       0.18      0.13      0.15        76
#               mini_cooper-sd       0.20      0.23      0.21        80
#                 nissan_nv400       0.47      0.44      0.45        80
#             nissan_primastar       0.28      0.41      0.33        46
#                  peugeot_108       0.14      0.14      0.14        80
#                  porsche_991       0.22      0.24      0.23        80
#                 suzuki_ignis       0.12      0.12      0.12        80
#               volkswagen_fox       0.12      0.11      0.12        80
#               volkswagen_up!       0.23      0.29      0.26        80
#
#                     accuracy                           0.22      1875
#                    macro avg       0.22      0.23      0.22      1875
#                 weighted avg       0.21      0.22      0.21      1875
